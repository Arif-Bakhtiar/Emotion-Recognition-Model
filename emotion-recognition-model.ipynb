# %%
#RAVDESS Speech Emotion Recognition by Arif
# MFCC Extraction + LSTM Model

# !pip install librosa soundfile tensorflow keras tqdm --quiet

import os
import librosa
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
DATA_PATH = "/kaggle/input/ravdess-emotional-speech-audio"

# %%
#Emotion labels according to filename convention
emotion_map = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fear',
    '07': 'disgust',
    '08': 'surprise'
}

# %%
#Feature Extraction Function (MFCCs)
def extract_features(file_path, max_len=216):
    audio, sr = librosa.load(file_path, duration=3, offset=0.5)
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)

    # Pad or slice MFCCs to ensure consistent length
    if mfcc.shape[1] < max_len:
        pad_width = max_len - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0,0),(0,pad_width)), mode='constant')
    else:
        mfcc = mfcc[:, :max_len]

    return mfcc

# %%
#Load Dataset and Extract Features
X, Y = [], []

print("Extracting MFCC features from RAVDESS dataset...\n")

for root, dirs, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)
            emotion_id = file.split("-")[2]     # "03" → happy
            emotion = emotion_map[emotion_id]

            features = extract_features(file_path)
            X.append(features)
            Y.append(emotion)

X = np.array(X)
Y = np.array(Y)

print("Feature extraction completed!")
print("X shape:", X.shape)
print("Y shape:", Y.shape)
# Out:
# Extracting MFCC features from RAVDESS dataset...
#
# Feature extraction completed!
# X shape: (2880, 40, 216)
# Y shape: (2880,)

# %%
#Encode Labels + Train/Test Split
encoder = LabelEncoder()
Y_encoded = encoder.fit_transform(Y)
Y_onehot = to_categorical(Y_encoded)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y_onehot, test_size=0.2, shuffle=True, random_state=42
)

print("\nTrain shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (2304, 40, 216)
# Test shape: (576, 40, 216)

# %%
#Build LSTM Model
model = Sequential([
    LSTM(128, return_sequences=False, input_shape=(40, 216)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(8, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 128)            │       176,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,416 (724.28 KB)
#  Trainable params: 185,416 (724.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train Model
history = model.fit(
    X_train, y_train,
    epochs=60,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1766 - loss: 2.1206 - val_accuracy: 0.3108 - val_loss: 1.8726
# Epoch 2/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3778 - loss: 1.7486 - val_accuracy: 0.4236 - val_loss: 1.6856
# Epoch 3/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5012 - loss: 1.4748 - val_accuracy: 0.5330 - val_loss: 1.4834
# Epoch 4/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6237 - loss: 1.2044 - val_accuracy: 0.5816 - val_loss: 1.2891
# Epoch 5/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7131 - loss: 0.9450 - val_accuracy: 0.6927 - val_loss: 1.0544
# Epoch 6/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7996 - loss: 0.7056 - val_accuracy: 0.7396 - val_loss: 0.8960
# Epoch 7/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8262 - loss: 0.5948 - val_accuracy: 0.7847 - val_loss: 0.7635
# Epoch 8/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8664 - loss: 0.4642 - val_accuracy: 0.8090 - val_loss: 0.6797
# Epoch 9/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9107 - loss: 0.3610 - val_accuracy: 0.8264 - val_loss: 0.5917
# Epoch 10/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0764 - val_accuracy: 0.8438 - val_loss: 0.7850
# Epoch 38/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9785 - loss: 0.0641 - val_accuracy: 0.8542 - val_loss: 0.7866
# Epoch 39/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9804 - loss: 0.0652 - val_accuracy: 0.8368 - val_loss: 0.7557
# Epoch 40/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9777 - loss: 0.0693 - val_accuracy: 0.8368 - val_loss: 0.7583
# Epoch 41/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0722 - val_accuracy: 0.8507 - val_loss: 0.7278
# Epoch 42/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9700 - loss: 0.0892 - val_accuracy: 0.8351 - val_loss: 0.7570
# Epoch 43/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.0799 - val_accuracy: 0.8247 - val_loss: 0.8284
# Epoch 44/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9766 - loss: 0.0741 - val_accuracy: 0.8455 - val_loss: 0.7415
# Epoch 45/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9864 - loss: 0.0616 - val_accuracy: 0.8507 - val_loss: 0.7154
# Epoch 46/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9757 - loss: 0.0757 - val_accuracy: 0.8611 - val_loss: 0.6960
# Epoch 47/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.0600 - val_accuracy: 0.8472 - val_loss: 0.7531
# Epoch 48/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9764 - loss: 0.0723 - val_accuracy: 0.8438 - val_loss: 0.7363
# Epoch 49/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9778 - loss: 0.0637 - val_accuracy: 0.8438 - val_loss: 0.7756
# Epoch 50/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9784 - loss: 0.0776 - val_accuracy: 0.8438 - val_loss: 0.7146
# Epoch 51/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9714 - loss: 0.0793 - val_accuracy: 0.8507 - val_loss: 0.7785
# Epoch 52/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.0457 - val_accuracy: 0.8472 - val_loss: 0.7992
# Epoch 53/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9803 - loss: 0.0533 - val_accuracy: 0.8385 - val_loss: 0.8334
# Epoch 54/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.0510 - val_accuracy: 0.8472 - val_loss: 0.8031
# Epoch 55/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9836 - loss: 0.0597 - val_accuracy: 0.8472 - val_loss: 0.7336
# Epoch 56/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0542 - val_accuracy: 0.8299 - val_loss: 0.8085
# Epoch 57/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9851 - loss: 0.0537 - val_accuracy: 0.8229 - val_loss: 0.9080
# Epoch 58/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9823 - loss: 0.0539 - val_accuracy: 0.8333 - val_loss: 0.8545
# Epoch 59/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0741 - val_accuracy: 0.8455 - val_loss: 0.8166
# Epoch 60/60
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9816 - loss: 0.0532 - val_accuracy: 0.8420 - val_loss: 0.7559

# %%
#Evaluate Model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nModel Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8350 - loss: 0.7653
#
# Model Test Accuracy: 84.20%

# %%
#Predict Emotion from Custom Audio File
def predict_emotion(audio_path):
    mfcc = extract_features(audio_path)
    mfcc = mfcc.reshape(1, 40, 216)

    pred = model.predict(mfcc)
    emotion = encoder.inverse_transform([np.argmax(pred)])
    return emotion[0]

# Example usage (upload your .wav file in Kaggle first):
# print(predict_emotion("/kaggle/input/yourfile.wav"))
